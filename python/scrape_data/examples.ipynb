# %%
# %load_ext autoreload
# %autoreload 2
# import everything from costar
from endpoints import fetch_costar_daily_horoscope_v1, fetch_costar_daily_horoscope_v2, fetch_chani_contentful_data

import json

def pretty_print(obj):
    print(json.dumps(obj, indent=4))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print(fetch_costar_daily_horoscope_v2(5, 14, 2024))
# Out:
# [{'contents': {'title': 'Your Taurus Sun knows how to use your hands. Give yourself a push.', 'titleValueIds': [2404077776219915871, 2404077776219799006, 2404077776219833161]}, 'type': 'ChaosMode'}, {'contents': {'body': "Today, something that felt dull becomes exciting. It feels like someone has flipped a switch inside your head, revealing hidden potential. You're due for a win.", 'bodyValueIds': [2403637971568828239, 2403637971568828909], 'columnOne': {'items': ['Eye on the prize', 'Full stops', 'See it through'], 'title': 'Do', 'valueIds': [2400031573429765903]}, 'columnTwo': {'items': ['Competitiveness', 'Cardigans', 'Voice notes'], 'title': "Don't", 'valueIds': [2399961204685590515]}, 'date': '2024-05-14', 'title': 'You can do it with ease, and look good doing it.', 'titleValueIds': [2402459295103837110]}, 'type': 'SelfModule'}, {'contents': {'bingoCard': ['Cinematic ending', 'Going off grid', 'Monk mode', 'Doom scrolling', 'Falling out of love', 'Losing faith', 'Listening on re
# ...

# %%
print(fetch_costar_daily_horoscope_v1(4, 19, 2023))
# Out:
# {'chartHighlight': {'diagramUrl': 'http://transit-diagrams-staging-deadbeef.elb.us-east-1.amazonaws.com:3000/?pname=Mars&ptag=Your%20aggression&cname=Capricorn&ctag=Great%0Acommitment&pangle=10313', 'summary': 'Your Mars is in Capricorn, which means that you have a greater self-sufficiency than everyone else. You are able to handle expectations with skill. Let your consistency lead the way. With that, you can take responsibility for your own actions.', 'title': 'Give yourself room to commit.', 'transitEnd': '2023-04-22T03:24:05Z', 'transitPeak': '2023-04-19T03:24:05Z', 'underlineContext': [5, 24], 'valueIds': [2400242679662264557, 2400242679662260119, 2400242679662264557, 2400189903104131310, 2400189903104112948, 2400189903104131310, 2400189903104131273, 2400189903104129324, 2400189903104131273, 2400189903104123831, 2400189903104126507, 2400189903104123831, 2400189903104131289, 2400189903104126873, 2400189903104131289, 2400137126545898481, 2400154718731929549, 2400154718731890537]}, 
# ...

# %%
print(fetch_chani_contentful_data())
# Out:
# {'sys': {'type': 'Array'}, 'total': 46, 'skip': 0, 'limit': 100, 'items': [{'metadata': {'tags': [{'sys': {'type': 'Link', 'linkType': 'Tag', 'id': 'ic'}}]}, 'sys': {'space': {'sys': {'type': 'Link', 'linkType': 'Space', 'id': 'hlytyi6rsuow'}}, 'id': '5WxVY1OtXkJzMzIV207CYr', 'type': 'Entry', 'createdAt': '2022-02-04T16:39:15.955Z', 'updatedAt': '2022-02-04T16:39:15.955Z', 'environment': {'sys': {'id': 'master', 'type': 'Link', 'linkType': 'Environment'}}, 'revision': 1, 'contentType': {'sys': {'type': 'Link', 'linkType': 'ContentType', 'id': 'planetInSignAspects'}}, 'locale': 'en-US'}, 'fields': {'title': 'IC conjunct Venus', 'otherPlanet': 'IC', 'risingSign': 'Conjunct', 'planet': 'Venus', 'planetPageHouse': '4', 'giftOrChallenge': 'gift', 'aspectDescription': 'With Venus on the IC, the planet of zhuzhing fluffs the pillows, rearranges the furniture, and adds fresh-cut flowers to every surface. \n\nYour home is a palace: a place where you don’t simply snooze in the moonlight hours,
# ...
